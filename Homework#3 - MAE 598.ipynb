# %% [markdown]
# ### Homework #3 - MAE 598
# Sebastian Garcia Peralta - 1213083648

# %% [markdown]
# ![Problem1Instructions.PNG](attachment:Problem1Instructions.PNG)

# %% [markdown]
# ### 1) Formulate the least square problem

# %% [markdown]
# ![Problem2Instructions-2.PNG](attachment:Problem2Instructions-2.PNG)

# %%
from bayes_opt import BayesianOptimization

def function(x,y):
    return 1/((4-2.1*x**2+(x**4)/3)*x**2+x*y+(-4+4*y**2)*y**2)
    
pbound = {'x':(-3,3),'y':(-2,2)}

optimizer = BayesianOptimization(f=function,pbounds=pbound,random_state=1)
optimizer.maximize(init_points=2,n_iter=10)
print(optimizer.max)
# Out:
# |   iter    |  target   |     x     |     y     |
# -------------------------------------------------
# |  1        | -3.773    | -0.4979   |  0.8813   |
# |  2        |  0.009079 | -2.999    | -0.7907   |
# |  3        |  0.01393  | -2.842    | -0.6774   |
# |  4        |  0.006627 |  3.0      | -2.0      |
# |  5        |  0.009141 |  3.0      |  0.2322   |
# |  6        |  0.01876  | -1.631    | -2.0      |
# |  7        |  0.02073  |  0.943    | -2.0      |
# |  8        |  0.006139 |  3.0      |  2.0      |
# |  9        |  0.006627 | -3.0      |  2.0      |
# |  10       |  1.049    |  1.97     | -0.8856   |
# |  11       |  0.4662   |  1.686    |  0.06022  |
# |  12       |  0.006762 | -2.949    | -1.99     |
# =================================================
# {'target': 1.049034961322794, 'params': {'x': 1.9695914072075538, 'y': -0.8856434079653994}}
